# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df_P1_1 = pd.read_excel("P001_001.xlsx")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_1['Pelvis_x'], df_P1_1["Pelvis_y"], linewidths=0.01,  color = 'red')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %%
df_P1_2 = pd.read_excel("P001_002.xlsx")
df_P1_3 = pd.read_excel("P001_003.xlsx")
df_P1_4 = pd.read_excel("P001_004.xlsx")
df_P1_5 = pd.read_excel("P001_005.xlsx")
df_P1_6 = pd.read_excel("P001_006.xlsx")
df_P1_7 = pd.read_excel("P001_007.xlsx")
df_P1_8 = pd.read_excel("P001_008_offaxis.xlsx")
df_P1_9 = pd.read_excel("P001_009.xlsx")
df_P1_10 = pd.read_excel("P001_010.xlsx")
df_P1_11 = pd.read_excel("P001_011.xlsx")
df_P1_12 = pd.read_excel("P001_012.xlsx")
df_P1_13 = pd.read_excel("P001_013.xlsx")
df_P1_14 = pd.read_excel("P001_014.xlsx")

# %% [markdown]
# # Sorting and picking
# ## without robot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_1['Pelvis_x'], df_P1_1["Pelvis_y"], linewidths=0.001)
ax.scatter(df_P1_2['Pelvis_x'], df_P1_2["Pelvis_y"], linewidths=0.001)
ax.scatter(df_P1_3['Pelvis_x'], df_P1_3["Pelvis_y"], linewidths=0.001)
ax.scatter(df_P1_4['Pelvis_x'], df_P1_4["Pelvis_y"], linewidths=0.001)
ax.scatter(df_P1_5['Pelvis_x'], df_P1_5["Pelvis_y"], linewidths=0.001)

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# # With robot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_6['Pelvis_x'], df_P1_6["Pelvis_y"], linewidth=0.01, color= '#88c999')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# ## Normal seanario

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_6['Pelvis_x'], df_P1_6["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_7['Pelvis_x'], df_P1_7["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_8['Pelvis_x'], df_P1_8["Pelvis_y"], linewidth=0.01)


ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# ## intervined

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_9['Pelvis_x'], df_P1_9["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_10['Pelvis_x'], df_P1_10["Pelvis_y"], linewidth=0.01)

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# ## normal and interumped Picking and sorting

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_6['Pelvis_x'], df_P1_6["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_7['Pelvis_x'], df_P1_7["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_8['Pelvis_x'], df_P1_8["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_9['Pelvis_x'], df_P1_9["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_10['Pelvis_x'], df_P1_10["Pelvis_y"], linewidth=0.01)

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# ## all the trajecory of picking and sorting

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_1['Pelvis_x'], df_P1_1["Pelvis_y"], linewidths=0.001, color = 'red')
ax.scatter(df_P1_2['Pelvis_x'], df_P1_2["Pelvis_y"], linewidths=0.001, color = 'red')
ax.scatter(df_P1_3['Pelvis_x'], df_P1_3["Pelvis_y"], linewidths=0.001, color = 'red')
ax.scatter(df_P1_4['Pelvis_x'], df_P1_4["Pelvis_y"], linewidths=0.001, color = 'red')
ax.scatter(df_P1_5['Pelvis_x'], df_P1_5["Pelvis_y"], linewidths=0.001, color = 'red')


ax.scatter(df_P1_6['Pelvis_x'], df_P1_6["Pelvis_y"], linewidth=0.01,  color = '#88c999')
ax.scatter(df_P1_7['Pelvis_x'], df_P1_7["Pelvis_y"], linewidth=0.01,  color = '#88c999')
ax.scatter(df_P1_8['Pelvis_x'], df_P1_8["Pelvis_y"], linewidth=0.01,  color = '#88c999')
ax.scatter(df_P1_9['Pelvis_x'], df_P1_9["Pelvis_y"], linewidth=0.01,  color = '#88c999')
ax.scatter(df_P1_10['Pelvis_x'], df_P1_10["Pelvis_y"], linewidth=0.01,  color = '#88c999')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# # Inventroy chicking

# %% [markdown]
# ## No robot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_11['Pelvis_x'], df_P1_11["Pelvis_y"], linewidth=0.01)
ax.scatter(df_P1_12['Pelvis_x'], df_P1_12["Pelvis_y"], linewidth=0.01)


ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# #With Robot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_13['Pelvis_x'], df_P1_13["Pelvis_y"], linewidths=0.001)
ax.scatter(df_P1_14['Pelvis_x'], df_P1_14["Pelvis_y"], linewidths=0.001)


ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()

# %% [markdown]
# ## All the senarios With and without robot

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.transforms import Affine2D
import numpy as np
from PIL import Image

fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(df_P1_11['Pelvis_x'], df_P1_11["Pelvis_y"], linewidths=0.0001,  color = 'red')
ax.scatter(df_P1_12['Pelvis_x'], df_P1_12["Pelvis_y"], linewidths=0.0001,  color = 'red')

ax.scatter(df_P1_13['Pelvis_x'], df_P1_13["Pelvis_y"], linewidths=0.0001,  color = '#88c999')
ax.scatter(df_P1_14['Pelvis_x'], df_P1_14["Pelvis_y"], linewidths=0.0001,  color = '#88c999')

ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')

Original_Image = Image.open("map_lprc.png")
  
rotated_image1 = Original_Image.rotate(-90)
ax.imshow(rotated_image1, extent=[-4, 10, -7, 4])
plt.show()
